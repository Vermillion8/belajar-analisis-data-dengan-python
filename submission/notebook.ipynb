# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Thalent Athalla Razzaq
# - **Email:** thalent.a.r@gmail.com
# - **ID Dicoding:** vermillion8631

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana korelasi tingkat partikulat di udara setiap jam
# - Bagaimana korelasi tingkat SO2 dan NO2 setiap bulan
# - Bagaimana korelasi tingkat CO dan O3 setiap tahun

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
aotizhongxin_df = pd.read_csv("data/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
changping_df = pd.read_csv("data/PRSA_Data_Changping_20130301-20170228.csv")

changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
dingling_df = pd.read_csv("data/PRSA_Data_Dingling_20130301-20170228.csv")

dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
dongsi_df = pd.read_csv("data/PRSA_Data_Dongsi_20130301-20170228.csv")

dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
guanyuan_df = pd.read_csv("data/PRSA_Data_Guanyuan_20130301-20170228.csv")

guanyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **For the rest of the project, I will use the first 5 csv files**

# %% [markdown]
# Assessing Aotizhongxin

# %%
aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Duplicates: ", aotizhongxin_df.duplicated().sum())
# Out:
# Duplicates:  0

# %%
aotizhongxin_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        545
# PM10         633
# SO2          330
# NO2          465
# CO           112
# O3           831
# TEMP         967
# PRES         600
# DEWP         604
# RAIN         127
# wd            16
# WSPM          91
# station        1
# dtype: int64

# %%
aotizhongxin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %% [markdown]
# Assessing Changping

# %%
changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
changping_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        481
# PM10         562
# SO2          294
# NO2          459
# CO           115
# O3           886
# TEMP         998
# PRES         592
# DEWP         602
# RAIN         116
# wd            16
# WSPM          95
# station        1
# dtype: int64

# %%
changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %% [markdown]
# Assessing Dingling

# %%
dingling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
dingling_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        486
# PM10         554
# SO2          327
# NO2          636
# CO           103
# O3           792
# TEMP         998
# PRES         593
# DEWP         602
# RAIN         116
# wd            16
# WSPM          95
# station        1
# dtype: int64

# %%
dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
dingling_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# ...

# %% [markdown]
# Assessing Dongsi

# %%
dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
dongsi_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        582
# PM10         666
# SO2          392
# NO2          701
# CO           115
# O3           737
# TEMP         963
# PRES         595
# DEWP         617
# RAIN         119
# wd            16
# WSPM         101
# station        1
# dtype: int64

# %%
dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
dongsi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# ...

# %% [markdown]
# Assessing Guanyuan

# %%
guanyuan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
guanyuan_df.nunique()
# Out:
# No         35064
# year           5
# month         12
# day           31
# hour          24
# PM2.5        557
# PM10         630
# SO2          280
# NO2          376
# CO           117
# O3           767
# TEMP         967
# PRES         600
# DEWP         604
# RAIN         127
# wd            16
# WSPM          91
# station        1
# dtype: int64

# %%
guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
guanyuan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Cleaning Aotizhongxin

# %%
aotizhongxin_df.duplicated().sum()
# Out:
# 0

# %%
aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
aotizhongxin_df[aotizhongxin_df["PM2.5"].isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10      SO2      NO2      CO  \
# 1509    1510  2013      5    2    21    NaN  183.0  63.0000  93.0000  1200.0
# 1837    1838  2013      5   16    13    NaN   98.0  46.0000  35.0000   600.0
# 2368    2369  2013      6    7    16    NaN  137.0  12.0000  74.0000  2500.0
# 2785    2786  2013      6   25     1    NaN   35.0   3.1416  35.1063     NaN
# 2808    2809  2013      6   26     0    NaN  183.0  64.2600  40.0335     NaN
# ...      ...   ...    ...  ...   ...    ...    ...      ...      ...     ...
# 34880  34881  2017      2   21     8    NaN    NaN      NaN      NaN     NaN
# 34883  34884  2017      2   21    11    NaN    NaN      NaN      NaN     NaN
# 34885  34886  2017      2   21    13    NaN    NaN      NaN      NaN     NaN
# 35028  35029  2017      2   27    12    NaN    NaN      NaN      NaN     NaN
# 35029  35030  2017      2   27    13    NaN    NaN      NaN      NaN     NaN
#
# ...

# %%
aotizhongxin_df.drop('wd', axis=1, inplace=True)
aotizhongxin_df.drop('TEMP', axis=1, inplace=True)
aotizhongxin_df.drop('PRES', axis=1, inplace=True)
aotizhongxin_df.drop('DEWP', axis=1, inplace=True)
aotizhongxin_df.drop('RAIN', axis=1, inplace=True)
aotizhongxin_df.drop('WSPM', axis=1, inplace=True)

aotizhongxin_df['PM2.5'] = aotizhongxin_df['PM2.5'].fillna(aotizhongxin_df['PM2.5'].mean())
aotizhongxin_df['PM10'] = aotizhongxin_df['PM10'].fillna(aotizhongxin_df['PM10'].mean())
aotizhongxin_df['SO2'] = aotizhongxin_df['SO2'].fillna(aotizhongxin_df['SO2'].mean())
aotizhongxin_df['NO2'] = aotizhongxin_df['NO2'].fillna(aotizhongxin_df['NO2'].mean())
aotizhongxin_df['CO'] = aotizhongxin_df['CO'].fillna(aotizhongxin_df['CO'].mean())
aotizhongxin_df['O3'] = aotizhongxin_df['O3'].fillna(aotizhongxin_df['O3'].mean())

# %%
aotizhongxin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# station    0
# dtype: int64

# %% [markdown]
# Cleaning Changping

# %%
changping_df.duplicated().sum()
# Out:
# 0

# %%
changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
changping_df.drop('wd', axis=1, inplace=True)
changping_df.drop('TEMP', axis=1, inplace=True)
changping_df.drop('PRES', axis=1, inplace=True)
changping_df.drop('DEWP', axis=1, inplace=True)
changping_df.drop('RAIN', axis=1, inplace=True)
changping_df.drop('WSPM', axis=1, inplace=True)

changping_df['PM2.5'] = changping_df['PM2.5'].fillna(changping_df['PM2.5'].mean())
changping_df['PM10'] = changping_df['PM10'].fillna(changping_df['PM10'].mean())
changping_df['SO2'] = changping_df['SO2'].fillna(changping_df['SO2'].mean())
changping_df['NO2'] = changping_df['NO2'].fillna(changping_df['NO2'].mean())
changping_df['CO'] = changping_df['CO'].fillna(changping_df['CO'].mean())
changping_df['O3'] = changping_df['O3'].fillna(changping_df['O3'].mean())

# %%
changping_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# station    0
# dtype: int64

# %% [markdown]
# Cleaning Dingling

# %%
dingling_df.duplicated().sum()
# Out:
# 0

# %%
dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
dingling_df.drop('wd', axis=1, inplace=True)
dingling_df.drop('TEMP', axis=1, inplace=True)
dingling_df.drop('PRES', axis=1, inplace=True)
dingling_df.drop('DEWP', axis=1, inplace=True)
dingling_df.drop('RAIN', axis=1, inplace=True)
dingling_df.drop('WSPM', axis=1, inplace=True)

dingling_df['PM2.5'] = dingling_df['PM2.5'].fillna(dingling_df['PM2.5'].mean())
dingling_df['PM10'] = dingling_df['PM10'].fillna(dingling_df['PM10'].mean())
dingling_df['SO2'] = dingling_df['SO2'].fillna(dingling_df['SO2'].mean())
dingling_df['NO2'] = dingling_df['NO2'].fillna(dingling_df['NO2'].mean())
dingling_df['CO'] = dingling_df['CO'].fillna(dingling_df['CO'].mean())
dingling_df['O3'] = dingling_df['O3'].fillna(dingling_df['O3'].mean())

# %%
dingling_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# station    0
# dtype: int64

# %% [markdown]
# Cleaning Dongsi

# %%
dongsi_df.duplicated().sum()
# Out:
# 0

# %%
dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
dongsi_df.drop('wd', axis=1, inplace=True)
dongsi_df.drop('TEMP', axis=1, inplace=True)
dongsi_df.drop('PRES', axis=1, inplace=True)
dongsi_df.drop('DEWP', axis=1, inplace=True)
dongsi_df.drop('RAIN', axis=1, inplace=True)
dongsi_df.drop('WSPM', axis=1, inplace=True)

dongsi_df['PM2.5'] = dongsi_df['PM2.5'].fillna(dongsi_df['PM2.5'].mean())
dongsi_df['PM10'] = dongsi_df['PM10'].fillna(dongsi_df['PM10'].mean())
dongsi_df['SO2'] = dongsi_df['SO2'].fillna(dongsi_df['SO2'].mean())
dongsi_df['NO2'] = dongsi_df['NO2'].fillna(dongsi_df['NO2'].mean())
dongsi_df['CO'] = dongsi_df['CO'].fillna(dongsi_df['CO'].mean())
dongsi_df['O3'] = dongsi_df['O3'].fillna(dongsi_df['O3'].mean())

# %%
dongsi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# station    0
# dtype: int64

# %% [markdown]
# Cleaning Guanyuan

# %%
guanyuan_df.duplicated().sum()
# Out:
# 0

# %%
guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
guanyuan_df.drop('wd', axis=1, inplace=True)
guanyuan_df.drop('TEMP', axis=1, inplace=True)
guanyuan_df.drop('PRES', axis=1, inplace=True)
guanyuan_df.drop('DEWP', axis=1, inplace=True)
guanyuan_df.drop('RAIN', axis=1, inplace=True)
guanyuan_df.drop('WSPM', axis=1, inplace=True)

guanyuan_df['PM2.5'] = guanyuan_df['PM2.5'].fillna(guanyuan_df['PM2.5'].mean())
guanyuan_df['PM10'] = guanyuan_df['PM10'].fillna(guanyuan_df['PM10'].mean())
guanyuan_df['SO2'] = guanyuan_df['SO2'].fillna(guanyuan_df['SO2'].mean())
guanyuan_df['NO2'] = guanyuan_df['NO2'].fillna(guanyuan_df['NO2'].mean())
guanyuan_df['CO'] = guanyuan_df['CO'].fillna(guanyuan_df['CO'].mean())
guanyuan_df['O3'] = guanyuan_df['O3'].fillna(guanyuan_df['O3'].mean())

# %%
guanyuan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# station    0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Aotizhongxin

# %%
aotizhongxin_df.sample(10)
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  \
# 27562  27563  2016      4   22    10   45.0  130.0   2.0   10.0   200.0
# 27110  27111  2016      4    3    14    6.0   16.0   2.0   10.0   300.0
# 34640  34641  2017      2   11     8   13.0   32.0  23.0   95.0  1300.0
# 27420  27421  2016      4   16    12   35.0   69.0   3.0    8.0   300.0
# 16549  16550  2015      1   19    13   49.0   84.0  30.0   76.0  1700.0
# 16128  16129  2015      1    2     0  109.0  134.0  49.0  100.0  2600.0
# 33441  33442  2016     12   23     9   19.0   19.0   7.0   55.0   700.0
# 14027  14028  2014     10    6    11   20.0   44.0   5.0   39.0   400.0
# 27073  27074  2016      4    2     1    7.0   22.0   9.0   21.0   200.0
# 18509  18510  2015      4   11     5  246.0  246.0  22.0   83.0  3500.0
#
#           O3       station
# 27562  111.0  Aotizhongxin
# 27110   98.0  Aotizhongxin
# 34640    8.0  Aotizhongxin
# 27420   82.0  Aotizhongxin
# 16549   20.0  Aotizhongxin
# ...

# %%
aotizhongxin_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
aotizhongxin_hour = aotizhongxin_df.groupby(by="hour").agg({
  "PM2.5": "mean",
  "PM10": "mean"
})

print(aotizhongxin_hour)

# Mean tingkat partikulat per jam pada kota Aotizhongxin dalam kurun waktu 5 tahun
# Out:
#           PM2.5        PM10
# hour
# 0     92.099235  124.350027
# 1     91.865678  123.402581
# 2     91.491893  120.106222
# 3     88.581518  114.429317
# 4     85.278254  109.071301
# 5     81.751254  103.495763
# 6     79.837240  100.584797
# 7     77.673445   98.930274
# 8     77.855941  101.430876
# 9     78.644881  103.663033
# 10    79.313291  103.386032
# 11    79.779294  101.941710
# 12    79.144203   98.807225
# 13    78.141710   96.313686
# 14    77.300351   98.013000
# 15    76.688725   99.302241
# 16    76.137783  101.981475
# 17    76.551174  106.988878
# 18    78.362792  113.081488
# 19    82.382800  118.385238
# 20    86.197830  124.224716
# 21    89.117391  126.797802
# 22    90.692509  127.357912
# 23    91.677469  125.403798

# %%
aotizhongxin_month = aotizhongxin_df.groupby(by="month").agg({
  "SO2": "mean",
  "NO2": "mean"
})

print(aotizhongxin_month)

# Mean tingkat SO2 dan NO2 per bulan pada kota Aotizhongxin dalam kurun waktu 5 tahun
# Out:
#              SO2        NO2
# month
# 1      34.788355  65.989555
# 2      30.963974  53.742529
# 3      31.560548  63.382581
# 4      16.432616  53.039104
# 5      16.068538  48.960845
# 6       8.511046  49.536572
# 7       5.943801  48.224902
# 8       4.578948  48.844430
# 9       7.341241  59.397238
# 10     10.815526  74.165288
# 11     15.907802  72.710775
# 12     26.116366  73.100737

# %%
aotizhongxin_year = aotizhongxin_df.groupby(by="year").agg({
  "CO": "mean",
  "O3": "mean"
})

print(aotizhongxin_year)

# Mean tingkat CO dan O3 per tahun pada kota Aotizhongxin dalam kurun waktu 5 tahun
# Out:
#                CO         O3
# year
# 2013  1187.527588  50.221417
# 2014  1194.545994  49.941810
# 2015  1395.649081  63.748528
# 2016  1196.488727  61.914457
# 2017  1668.531169  47.573536

# %% [markdown]
# ### Explore Changping

# %%
changping_df.sample(10)
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2   NO2      CO     O3  \
# 23486  23487  2015     11    4    14  191.0  191.0  24.0  68.0  1100.0   55.0
# 30929  30930  2016      9    9    17   13.0   25.0   5.0  17.0   700.0   80.0
# 15002  15003  2014     11   16     2  112.0  129.0  32.0  81.0  2200.0    4.0
# 16986  16987  2015      2    6    18   59.0   68.0  26.0  72.0  1100.0   34.0
# 22901  22902  2015     10   11     5   17.0   17.0   6.0  29.0   300.0   40.0
# 27184  27185  2016      4    6    16  148.0  223.0  35.0  98.0  2500.0   71.0
# 19388  19389  2015      5   17    20  166.0  196.0   5.0  55.0  1400.0   97.0
# 25243  25244  2016      1   16    19  117.0  160.0  35.0  92.0  2300.0    5.0
# 20131  20132  2015      6   17    19   21.0   44.0   2.0  14.0   500.0  140.0
# 28210  28211  2016      5   19    10  123.0  144.0  12.0  56.0   900.0  190.0
#
#          station
# 23486  Changping
# 30929  Changping
# 15002  Changping
# 16986  Changping
# 22901  Changping
# ...

# %%
changping_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
changping_hour = changping_df.groupby(by="hour").agg({
  "PM2.5": "mean",
  "PM10": "mean"
})

print(changping_hour)

# Mean tingkat partikulat per jam pada kota Changping dalam kurun waktu 5 tahun
# Out:
#           PM2.5        PM10
# hour
# 0     72.479050   93.372672
# 1     71.614711   89.558161
# 2     69.973781   86.397370
# 3     67.998695   83.815969
# 4     65.587539   80.354894
# 5     63.876108   78.738643
# 6     63.198764   80.116250
# 7     64.324774   86.061601
# 8     67.430592   92.782935
# 9     71.787129   99.712219
# 10    75.768235  104.045715
# 11    75.792464  101.420079
# 12    74.898897   97.585251
# 13    72.183222   92.911956
# 14    70.033187   91.848733
# 15    69.506768   94.526838
# 16    68.252559   94.248085
# 17    69.336680   97.615169
# 18    72.031548  102.896033
# 19    75.673779  108.785687
# 20    77.949549  111.479214
# 21    77.923609  107.259159
# 22    75.297256  100.617691
# 23    73.474944   95.638575

# %%
changping_month = changping_df.groupby(by="month").agg({
  "SO2": "mean",
  "NO2": "mean"
})

print(changping_month)

# Mean tingkat SO2 dan NO2 per bulan pada kota Changping dalam kurun waktu 5 tahun
# Out:
#              SO2        NO2
# month
# 1      31.997680  57.473090
# 2      29.005420  48.097686
# 3      25.689319  55.047254
# 4      11.599498  41.201785
# 5      12.001953  34.437991
# 6       7.331004  30.191973
# 7       4.946152  27.400718
# 8       4.514597  27.829214
# 9       5.136660  38.240292
# 10      7.202063  52.890023
# 11     15.143215  56.365728
# 12     25.520038  61.010540

# %%
changping_year = changping_df.groupby(by="year").agg({
  "CO": "mean",
  "O3": "mean"
})

print(changping_year)

# Mean tingkat CO dan O3 per tahun pada kota Changping dalam kurun waktu 5 tahun
# Out:
#                CO         O3
# year
# 2013  1052.052075  61.399195
# 2014  1195.430974  63.080795
# 2015  1161.859538  57.912187
# 2016  1123.589296  53.904720
# 2017  1524.400162  33.400410

# %% [markdown]
# Explore Dingling

# %%
dingling_df.sample(10)
# Out:
#           No  year  month  day  hour  PM2.5   PM10       SO2   NO2  \
# 17386  17387  2015      2   23    10   29.0   90.0  29.00000   6.0
# 23070  23071  2015     10   18     6    6.0    8.0   2.00000  15.0
# 29956  29957  2016      7   31     4   42.0   42.0   2.00000  10.0
# 2186    2187  2013      5   31     2   45.0  100.0   8.00000  22.0
# 4288    4289  2013      8   26    16   15.0   28.0   2.00000   5.0
# 30070  30071  2016      8    4    22   93.0   93.0   2.00000  12.0
# 13354  13355  2014      9    8    10    3.0    5.0   7.00000  12.0
# 28413  28414  2016      5   27    21   87.0  193.0  11.74965  29.0
# 4469    4470  2013      9    3     5   71.0   50.0   1.00000   6.0
# 24372  24373  2015     12   11    12   29.0   29.0  16.00000  34.0
#
#                 CO     O3   station
# 17386   500.000000   55.0  Dingling
# 23070   400.000000   59.0  Dingling
# 29956   904.896073   47.0  Dingling
# 2186    600.000000   91.0  Dingling
# 4288    200.000000  162.0  Dingling
# ...

# %%
dingling_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
dingling_hour = dingling_df.groupby(by="hour").agg({
  "PM2.5": "mean",
  "PM10": "mean"
})

print(dingling_hour)

# Mean tingkat partikulat per jam pada kota Dingling dalam kurun waktu 5 tahun
# Out:
#           PM2.5       PM10
# hour
# 0     66.294755  80.966238
# 1     66.162312  78.483719
# 2     64.493448  76.533986
# 3     61.738183  73.399201
# 4     60.305001  71.359940
# 5     58.666898  69.688305
# 6     57.597356  69.263199
# 7     57.765666  72.367963
# 8     60.244865  77.444432
# 9     63.873872  81.989319
# 10    66.660968  84.457982
# 11    67.757179  86.633326
# 12    69.341497  89.593789
# 13    69.539653  88.433051
# 14    68.806730  88.033862
# 15    69.220578  89.239928
# 16    69.035686  91.424198
# 17    69.910869  94.070551
# 18    71.180490  97.095506
# 19    71.236522  97.780089
# 20    69.928622  94.076708
# 21    69.102166  89.315245
# 22    67.647927  84.935942
# 23    67.236684  83.166881

# %%
dingling_month = dingling_df.groupby(by="month").agg({
  "SO2": "mean",
  "NO2": "mean"
})

print(dingling_month)

# Mean tingkat SO2 dan NO2 per bulan pada kota Dingling dalam kurun waktu 5 tahun
# Out:
#              SO2        NO2
# month
# 1      23.089576  38.763837
# 2      19.933619  28.091001
# 3      18.554886  34.146156
# 4       9.661504  25.919554
# 5       9.424156  20.418155
# 6       5.605350  17.865729
# 7       4.341782  16.397687
# 8       4.405743  13.980949
# 9       4.609646  18.281917
# 10      7.314855  30.595611
# 11     14.194842  42.696713
# 12     20.168824  43.733202

# %%
dingling_year = dingling_df.groupby(by="year").agg({
  "CO": "mean",
  "O3": "mean"
})

print(dingling_year)

# Mean tingkat CO dan O3 per tahun pada kota Dingling dalam kurun waktu 5 tahun
# Out:
#                CO         O3
# year
# 2013   852.777553  65.187935
# 2014   877.656411  72.515434
# 2015   966.453378  70.953036
# 2016   874.441321  67.357060
# 2017  1151.824317  53.948925

# %% [markdown]
# Explore Dongsi

# %%
dongsi_df.sample(10)
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2           CO  \
# 26801  26802  2016      3   21    17  135.0  198.0  33.0   46.0  1000.000000
# 23053  23054  2015     10   17    13  315.0  315.0  43.0  102.0  2200.000000
# 32007  32008  2016     10   24    15   81.0   93.0   3.0   64.0  1100.000000
# 19945  19946  2015      6   10     1   38.0   38.0   9.0   26.0   700.000000
# 34359  34360  2017      1   30    15   11.0   11.0   5.0   19.0   400.000000
# 33726  33727  2017      1    4     6  540.0  571.0  16.0  189.0  1330.069131
# 19001  19002  2015      5    1    17   34.0   34.0   2.0   19.0   600.000000
# 20814  20815  2015      7   16     6   61.0   61.0   2.0   20.0   800.000000
# 10219  10220  2014      4   30    19   79.0  172.0  21.0   27.0   800.000000
# 16313  16314  2015      1    9    17    8.0   15.0  10.0   34.0   500.000000
#
#           O3 station
# 26801  132.0  Dongsi
# 23053   60.0  Dongsi
# 32007    4.0  Dongsi
# 19945   66.0  Dongsi
# ...

# %%
dongsi_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
dongsi_hour = dongsi_df.groupby(by="hour").agg({
  "PM2.5": "mean",
  "PM10": "mean"
})

print(dongsi_hour)

# Mean tingkat partikulat per jam pada kota Dongsi dalam kurun waktu 5 tahun
# Out:
#           PM2.5        PM10
# hour
# 0     96.944408  124.497185
# 1     96.449602  121.676522
# 2     94.900522  118.950238
# 3     92.505644  114.242424
# 4     89.114474  108.771208
# 5     85.188198  103.779422
# 6     82.360348  102.352540
# 7     80.403188  101.576659
# 8     80.006002  102.737370
# 9     79.685449  102.504268
# 10    79.814313  101.989310
# 11    80.657687  101.110463
# 12    80.519985   98.555457
# 13    80.729747   97.746595
# 14    79.406301   96.900117
# 15    78.415426   98.371279
# 16    78.364837  100.875797
# 17    78.954229  103.926127
# 18    81.675561  112.272018
# 19    87.191411  120.630003
# 20    93.342951  127.858142
# 21    97.281567  130.643599
# 22    97.444784  129.114361
# 23    97.306489  127.000701

# %%
dongsi_month = dongsi_df.groupby(by="month").agg({
  "SO2": "mean",
  "NO2": "mean"
})

print(dongsi_month)

# Mean tingkat SO2 dan NO2 per bulan pada kota Dongsi dalam kurun waktu 5 tahun
# Out:
#              SO2        NO2
# month
# 1      33.324329  59.609047
# 2      30.634584  47.513070
# 3      30.474448  61.681691
# 4      16.598591  47.304354
# 5      17.588620  45.381904
# 6      11.079100  45.817824
# 7       7.922997  41.804062
# 8       6.207674  41.458301
# 9       8.321636  53.840442
# 10     12.318285  68.320225
# 11     19.333428  64.171004
# 12     29.037099  66.824399

# %%
dongsi_year = dongsi_df.groupby(by="year").agg({
  "CO": "mean",
  "O3": "mean"
})

print(dongsi_year)

# Mean tingkat CO dan O3 per tahun pada kota Dongsi dalam kurun waktu 5 tahun
# Out:
#                CO         O3
# year
# 2013  1335.308738  63.489913
# 2014  1367.693735  57.245953
# 2015  1335.668400  55.796035
# 2016  1243.028459  56.145993
# 2017  1575.439513  39.780815

# %% [markdown]
# Explore Guanyuan

# %%
guanyuan_df.sample(10)
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2           CO  \
# 8256    8257  2014      2    8     0   79.0   56.0  18.0   61.0  1300.000000
# 2697    2698  2013      6   21     9   46.0   94.0   8.0   77.0  1000.000000
# 6655    6656  2013     12    3     7   46.0  129.0  38.0   62.0  1271.294377
# 25759  25760  2016      2    7     7   34.0   60.0  22.0   74.0  1500.000000
# 21819  21820  2015      8   27     3   17.0   21.0   2.0   32.0   500.000000
# 17885  17886  2015      3   16     5  144.0  210.0  44.0  104.0  2200.000000
# 16333  16334  2015      1   10    13  111.0  111.0  41.0  116.0  2600.000000
# 9410    9411  2014      3   28     2  139.0  195.0  31.0   98.0  1800.000000
# 15689  15690  2014     12   14    17   85.0  120.0  39.0  103.0  1700.000000
# 22526  22527  2015      9   25    14   15.0   15.0   2.0   11.0   200.000000
#
#               O3   station
# 8256   15.000000  Guanyuan
# 2697   40.000000  Guanyuan
# 6655   55.795044  Guanyuan
# ...

# %%
guanyuan_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
guanyuan_hour = guanyuan_df.groupby(by="hour").agg({
  "PM2.5": "mean",
  "PM10": "mean"
})

print(guanyuan_hour)

# Mean tingkat partikulat per jam pada kota Guanyuan dalam kurun waktu 5 tahun
# Out:
#           PM2.5        PM10
# hour
# 0     91.064842  120.067985
# 1     90.319850  116.857903
# 2     88.188456  113.153696
# 3     86.536140  108.621058
# 4     84.164545  104.847636
# 5     81.096053  101.382838
# 6     79.469542  100.581953
# 7     78.296236  101.585902
# 8     78.439425  104.141143
# 9     79.031668  105.018156
# 10    78.737624  104.515751
# 11    79.517136  104.680620
# 12    79.008443  100.925220
# 13    79.154644   98.639607
# 14    78.436688   98.380912
# 15    77.178281   99.521722
# 16    76.169793  101.427793
# 17    77.248963  104.913424
# 18    80.271687  111.627971
# 19    85.126466  118.369012
# 20    89.266006  124.243433
# 21    90.953890  125.686333
# 22    91.179740  124.286345
# 23    91.544810  123.082859

# %%
guanyuan_month = guanyuan_df.groupby(by="month").agg({
  "SO2": "mean",
  "NO2": "mean"
})

print(guanyuan_month)

# Mean tingkat SO2 dan NO2 per bulan pada kota Guanyuan dalam kurun waktu 5 tahun
# Out:
#              SO2        NO2
# month
# 1      34.692751  69.963558
# 2      31.225564  58.156910
# 3      31.296104  67.314488
# 4      15.547595  54.030432
# 5      15.741359  48.583330
# 6       8.532307  43.633515
# 7       7.184446  41.068021
# 8       5.012263  44.261755
# 9       6.775736  53.687297
# 10      9.113703  67.932448
# 11     17.105250  69.668519
# 12     29.351069  76.200572

# %%
guanyuan_year = guanyuan_df.groupby(by="year").agg({
  "CO": "mean",
  "O3": "mean"
})

print(guanyuan_year)

# Mean tingkat CO dan O3 per tahun pada kota Guanyuan dalam kurun waktu 5 tahun
# Out:
#                CO         O3
# year
# 2013  1197.387065  58.196017
# 2014  1351.308925  55.262818
# 2015  1314.617354  56.758876
# 2016  1174.867143  54.945471
# 2017  1489.765711  45.942674

# %% [markdown]
# **Explore Correlation of Particulate Matter For All Cities**

# %%
aotizhongxinHour_corr = aotizhongxin_hour.corr(numeric_only=True)
changpingHour_corr = changping_hour.corr(numeric_only=True)
dinglingHour_corr = dingling_hour.corr(numeric_only=True)
dongsiHour_corr = dongsi_hour.corr(numeric_only=True)
guanyuanHour_corr = guanyuan_hour.corr(numeric_only=True)

# Getting correlation of particulate matter for all cities

# %%
merged_hour = pd.concat([aotizhongxinHour_corr, changpingHour_corr, dinglingHour_corr, dongsiHour_corr, guanyuanHour_corr], axis=1, join="outer")
merged_hour.columns = ['Aotizhongxin_PM2.5', 'Aotizhongxin_PM10', 'Changping_PM2.5', 'Changping_PM10', 'Dingling_PM2.5', 'Dingling_PM10', 'Dongsi_PM2.5', 'Dongsi_PM10', 'Guanyuan_PM2.5', 'Guanyuan_PM10']
print(merged_hour)

# Merging the particulate matter data into one dataframe
# Out:
#        Aotizhongxin_PM2.5  Aotizhongxin_PM10  Changping_PM2.5  Changping_PM10  \
# PM2.5            1.000000           0.885091         1.000000        0.886478
# PM10             0.885091           1.000000         0.886478        1.000000
#
#        Dingling_PM2.5  Dingling_PM10  Dongsi_PM2.5  Dongsi_PM10  \
# PM2.5        1.000000       0.945182      1.000000     0.928791
# PM10         0.945182       1.000000      0.928791     1.000000
#
#        Guanyuan_PM2.5  Guanyuan_PM10
# PM2.5        1.000000       0.905738
# PM10         0.905738       1.000000

# %% [markdown]
# **Explore Correlation Of SO2 & NO2 For All Cities**

# %%
aotizhongxinMonth_corr = aotizhongxin_month.corr(numeric_only=True)
changpingMonth_corr = changping_month.corr(numeric_only=True)
dinglingMonth_corr = dingling_month.corr(numeric_only=True)
dongsiMonth_corr = dongsi_month.corr(numeric_only=True)
guanyuanMonth_corr = guanyuan_month.corr(numeric_only=True)

# Getting correlation of SO2 & NO2 for all cities

# %%
merged_month = pd.concat([aotizhongxinMonth_corr, changpingMonth_corr, dinglingMonth_corr, dongsiMonth_corr, guanyuanMonth_corr], axis=1, join="outer")
merged_month.columns = ['Aotizhongxin_SO2', 'Aotizhongxin_NO2', 'Changping_SO2', 'Changping_NO2', 'Dingling_SO2', 'Dingling_NO2', 'Dongsi_SO2', 'Dongsi_NO2', 'Guanyuan_SO2', 'Guanyuan_NO2']
print(merged_month)
# Out:
#      Aotizhongxin_SO2  Aotizhongxin_NO2  Changping_SO2  Changping_NO2  \
# SO2          1.000000          0.383308       1.000000       0.750171
# NO2          0.383308          1.000000       0.750171       1.000000
#
#      Dingling_SO2  Dingling_NO2  Dongsi_SO2  Dongsi_NO2  Guanyuan_SO2  \
# SO2       1.00000       0.81674    1.000000    0.474596      1.000000
# NO2       0.81674       1.00000    0.474596    1.000000      0.687115
#
#      Guanyuan_NO2
# SO2      0.687115
# NO2      1.000000

# %% [markdown]
# **Explore Correlation of CO & O3 For All Cities**

# %%
aotizhongxinYear_corr = aotizhongxin_year.corr(numeric_only=True)
changpingYear_corr = changping_year.corr(numeric_only=True)
dinglingYear_corr = dingling_year.corr(numeric_only=True)
dongsiYear_corr = dongsi_year.corr(numeric_only=True)
guanyuanYear_corr = guanyuan_year.corr(numeric_only=True)

# Getting correlation of CO & O3 for all cities

# %%
merged_year = pd.concat([aotizhongxinYear_corr, changpingYear_corr, dinglingYear_corr, dongsiYear_corr, guanyuanYear_corr], axis=1, join="outer")
merged_year.columns = ['Aotizhongxin_CO', 'Aotizhongxin_O3', 'Changping_CO', 'Changping_O3', 'Dingling_CO', 'Dingling_O3', 'Dongsi_CO', 'Dongsi_O3', 'Guanyuan_CO', 'Guanyuan_O3']
print(merged_year)
# Out:
#     Aotizhongxin_CO  Aotizhongxin_O3  Changping_CO  Changping_O3  Dingling_CO  \
# CO         1.000000        -0.237408      1.000000     -0.905796     1.000000
# O3        -0.237408         1.000000     -0.905796      1.000000    -0.784717
#
#     Dingling_O3  Dongsi_CO  Dongsi_O3  Guanyuan_CO  Guanyuan_O3
# CO    -0.784717   1.000000  -0.829645     1.000000    -0.808263
# O3     1.000000  -0.829645   1.000000    -0.808263     1.000000

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# Bagaimana korelasi tingkat partikulat di udara setiap jam

# Define the city names
cities = ['aotizhongxin', 'changping', 'dingling', 'dongsi', 'guanyuan']

# Iterate over the city names
for city in cities:
    # Get the corresponding dataframe
    df = globals()[f"{city}_hour"]
    print(globals()[f"{city}Hour_corr"])
    
    # Create a scatter plot
    plt.scatter(df['PM2.5'], df['PM10'])
    
    # Set the x-axis label
    plt.xlabel('PM2.5')
    
    # Set the y-axis label
    plt.ylabel('PM10')
    
    # Set the title of the plot
    plt.title(f'Scatter Plot for {city.capitalize()}')
    
    # Display the plot
    plt.show()
# Out:
#           PM2.5      PM10
# PM2.5  1.000000  0.885091
# PM10   0.885091  1.000000
#           PM2.5      PM10
# PM2.5  1.000000  0.886478
# PM10   0.886478  1.000000
#           PM2.5      PM10
# PM2.5  1.000000  0.945182
# PM10   0.945182  1.000000
#           PM2.5      PM10
# PM2.5  1.000000  0.928791
# PM10   0.928791  1.000000
#           PM2.5      PM10
# PM2.5  1.000000  0.905738
# PM10   0.905738  1.000000

# %%
merged_hour.replace(1, np.nan, inplace=True) # Replace 1 with NaN
merged_hour_flat = pd.Series(merged_hour.values.ravel()).drop_duplicates() # Flatten the dataframe and drop duplicates
print(merged_hour_flat.mean()) # Get the mean of the flattened dataframe

# The mean of the correlation of particulate matter for all cities
# Out:
# 0.9102559819552505

# %% [markdown]
# From the data analyzed, there is a positive correlation between PM2.5 and PM10 every hour for 5 years. With 5 stations analyzed, Aotizhongxin, Changping, Dingling, Dongsi, Guanyuan, there is a **strong positive relationship** between PM2.5 and PM10 **(91%)**. When one rises, there is a strong tendency for the other to rise as well.

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Bagaimana korelasi tingkat partikulat di udara setiap jam

# Define the city names
cities = ['aotizhongxin', 'changping', 'dingling', 'dongsi', 'guanyuan']

# Iterate over the city names
for city in cities:
    # Get the corresponding dataframe
    df = globals()[f"{city}_month"]
    print(globals()[f"{city}Month_corr"])
    
    # Create a scatter plot
    plt.scatter(df['SO2'], df['NO2'])
    
    # Set the x-axis label
    plt.xlabel('SO2')
    
    # Set the y-axis label
    plt.ylabel('NO2')
    
    # Set the title of the plot
    plt.title(f'Scatter Plot for {city.capitalize()}')
    
    # Display the plot
    plt.show()
# Out:
#           SO2       NO2
# SO2  1.000000  0.383308
# NO2  0.383308  1.000000
#           SO2       NO2
# SO2  1.000000  0.750171
# NO2  0.750171  1.000000
#          SO2      NO2
# SO2  1.00000  0.81674
# NO2  0.81674  1.00000
#           SO2       NO2
# SO2  1.000000  0.474596
# NO2  0.474596  1.000000
#           SO2       NO2
# SO2  1.000000  0.687115
# NO2  0.687115  1.000000

# %%
merged_month.replace(1, np.nan, inplace=True) # Replace 1 with NaN
merged_month_flat = pd.Series(merged_month.values.ravel()).drop_duplicates() # Flatten the dataframe and drop duplicates
print(merged_month_flat.mean()) # Get the mean of the flattened dataframe

# The mean of the correlation of SO2 & NO2 for all cities
# Out:
# 0.6223858237926541

# %% [markdown]
# From the data analyzed, there is a positive correlation between NO2 and SO2 every month for 5 years. With 5 stations analyzed, Aotizhongxin, Changping, Dingling, Dongsi, Guanyuan, there is a **moderate positive relationship** between NO2 and SO2 **(62.2%)**. When one rises, there is a moderate tendency for the other to rise as well.

# %% [markdown]
# ### Pertanyaan 3:

# %%
# Bagaimana korelasi tingkat CO dan O3 setiap tahun

# Define the city names
cities = ['aotizhongxin', 'changping', 'dingling', 'dongsi', 'guanyuan']

# Iterate over the city names
for city in cities:
    # Get the corresponding dataframe
    df = globals()[f"{city}_year"]
    print(globals()[f"{city}Year_corr"])
    
    # Create a scatter plot
    plt.scatter(df['CO'], df['O3'])
    
    # Set the x-axis label
    plt.xlabel('CO')
    
    # Set the y-axis label
    plt.ylabel('O3')
    
    # Set the title of the plot
    plt.title(f'Scatter Plot for {city.capitalize()}')
    
    # Display the plot
    plt.show()
# Out:
#           CO        O3
# CO  1.000000 -0.237408
# O3 -0.237408  1.000000
#           CO        O3
# CO  1.000000 -0.905796
# O3 -0.905796  1.000000
#           CO        O3
# CO  1.000000 -0.784717
# O3 -0.784717  1.000000
#           CO        O3
# CO  1.000000 -0.829645
# O3 -0.829645  1.000000
#           CO        O3
# CO  1.000000 -0.808263
# O3 -0.808263  1.000000

# %%
merged_year.replace(1, np.nan, inplace=True) # Replace 1 with NaN
merged_year_flat = pd.Series(merged_year.values.ravel()).drop_duplicates() # Flatten the dataframe and drop duplicates
print(merged_year_flat.mean()) # Get the mean of the flattened dataframe

# The mean of the correlation of CO & O3 for all cities
# Out:
# -0.7131657759193208

# %% [markdown]
# From the data analyzed, there is a positive correlation between CO and O3 every year for 5 years. With 5 station analyzed, Aotizhongxin, Changping, Dingling, Dongsi, Guanyuan, there is a **moderate negative relationship** between CO and O3 **(-71.3%)**. When one rises, there is a moderate tendency for the other to decrease.

# %% [markdown]
# Bar chart for each question

# %%
categories = ['PM2.5 & PM10', 'SO2 & NO2', 'CO & O3']
values = [merged_hour_flat.mean(), merged_month_flat.mean(), merged_year_flat.mean()]
colors = ['red', 'green', 'blue']

plt.bar(categories, values, color=colors)
plt.ylim(-1, 1)
plt.xlabel('Categories')
plt.ylabel('Mean Correlation')
plt.title('Mean Correlation of Different Categories')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Data yang digunakan meliputi 5 stasiun (Aotizhongxin, Changping, Dingling, Dongsi, Guanyuan) dengan data 5 tahun
#
# - Dari data yang sudah dianalisa, PM2.5 dan PM10 memiliki korelasi positif sehigga ketika salah satu meningkat, satunya juga meningkat. Analisa berdasarkan data PM2.5 dan PM10 setiap jam selama 5 tahun.
# - Dari data yang sudah dianalisa, SO2 dan NO2 memiliki korelasi positif sehingga ketika salah satu meningkat, satunya juga meningkat. Analisa berdasarkan data SO2 dan NO2 setiap bulan selama 5 tahun.
# - Dari data yang sudah dianalisa, CO dan O3 memiliki korelasi negatif sehingga ketika salah satu meningkat, satunya akan menyusut. Analisa berdasarkan data CO dan O3 setiap tahun selama 5 tahun.

# %%
merged_hour.to_csv('dashboard/merged_hour.csv')
merged_month.to_csv('dashboard/merged_month.csv')
merged_year.to_csv('dashboard/merged_year.csv')
